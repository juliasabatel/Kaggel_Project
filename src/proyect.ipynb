# %% [markdown]
# # SET UP

# %%
import pandas as pd
import sklearn.datasets
import numpy as np
import seaborn as sns

from sklearn.metrics import confusion_matrix, accuracy_score
pd.set_option('display.max_columns', None)

from sklearn.model_selection import train_test_split as tts

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
train = pd.read_csv("../Kaggle_Competition/data/salaries_data.csv",encoding='latin1')

# %%
y= train[['salary_in_usd']]

# %%
train.head()
# Out:
#    work_year experience_level employment_type        job_title  salary  \
# 0       2022               SE              FT    Data Engineer  140250
# 1       2022               SE              FT    Data Engineer  135000
# 2       2021               MI              FT  BI Data Analyst  100000
# 3       2021               MI              CT      ML Engineer  270000
# 4       2021               MI              FT    Data Engineer   22000
#
#   salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0             USD         140250                 US           100
# 1             USD         135000                 US           100
# 2             USD         100000                 US           100
# 3             USD         270000                 US           100
# 4             EUR          26005                 RO             0
#
#   company_location company_size
# 0               US            M
# 1               US            M
# 2               US            M
# ...

# %%
test = pd.read_csv('../Kaggle_Competition/data/testeo.csv', encoding='latin1')

# %%
test.head()
# Out:
#    work_year experience_level employment_type                   job_title  \
# 0       2020               SE              FT  Machine Learning Scientist
# 1       2020               MI              FT           Lead Data Analyst
# 2       2020               MI              FT                Data Analyst
# 3       2020               MI              FT   Machine Learning Engineer
# 4       2020               MI              FT        Product Data Analyst
#
#    salary salary_currency employee_residence  remote_ratio company_location  \
# 0  260000             USD                 JP             0               JP
# 1   87000             USD                 US           100               US
# 2   85000             USD                 US           100               US
# 3  299000             CNY                 CN             0               CN
# 4  450000             INR                 IN           100               IN
#
#   company_size
# 0            S
# 1            L
# ...

# %% [markdown]
# # EXPLORATION

# %%
len(train.columns)
# Out:
# 11

# %%
len(test.columns)
# Out:
# 10

# %%
train.columns
# Out:
# Index(['work_year', 'experience_level', 'employment_type', 'job_title',
#        'salary', 'salary_currency', 'salary_in_usd', 'employee_residence',
#        'remote_ratio', 'company_location', 'company_size'],
#       dtype='object')

# %%
test.columns
# Out:
# Index(['work_year', 'experience_level', 'employment_type', 'job_title',
#        'salary', 'salary_currency', 'employee_residence', 'remote_ratio',
#        'company_location', 'company_size'],
#       dtype='object')

# %%
#cols=['salary','salary_currency']

#train.drop(columns=cols, inplace=True)

# %%
len(train.columns) #la hemos eliminado para que ambas sean 10 y ahora haremos concat
# Out:
# 11

# %%
train2 = pd.concat([train,test])

# %%
cols1 =['salary','salary_currency','salary_in_usd']
train2.drop(columns=cols1, inplace=True)

# %%
train2.head()
# Out:
#    work_year experience_level employment_type        job_title  \
# 0       2022               SE              FT    Data Engineer
# 1       2022               SE              FT    Data Engineer
# 2       2021               MI              FT  BI Data Analyst
# 3       2021               MI              CT      ML Engineer
# 4       2021               MI              FT    Data Engineer
#
#   employee_residence  remote_ratio company_location company_size
# 0                 US           100               US            M
# 1                 US           100               US            M
# 2                 US           100               US            M
# 3                 US           100               US            L
# 4                 RO             0               US            L

# %%
len(train2)
# Out:
# 607

# %%
len(train2.columns)
# Out:
# 8

# %%
train2.dtypes
# Out:
# work_year              int64
# experience_level      object
# employment_type       object
# job_title             object
# employee_residence    object
# remote_ratio           int64
# company_location      object
# company_size          object
# dtype: object

# %%
train2.work_year.value_counts() #en principio se puede dejar así
# Out:
# 2022    318
# 2021    217
# 2020     72
# Name: work_year, dtype: int64

# %%
train2.experience_level.value_counts() #en principio se puede dejar así
# Out:
# SE    280
# MI    213
# EN     88
# EX     26
# Name: experience_level, dtype: int64

# %%
train2.employment_type.value_counts() #en principio se puede dejar así
# Out:
# FT    588
# PT     10
# CT      5
# FL      4
# Name: employment_type, dtype: int64

# %%
train2.job_title.value_counts() #hay que limpiar
# Out:
# Data Scientist                              143
# Data Engineer                               132
# Data Analyst                                 97
# Machine Learning Engineer                    41
# Research Scientist                           16
# Data Science Manager                         12
# Data Architect                               11
# Big Data Engineer                             8
# Machine Learning Scientist                    8
# Director of Data Science                      7
# AI Scientist                                  7
# Data Analytics Manager                        7
# Principal Data Scientist                      7
# Data Science Consultant                       7
# Computer Vision Engineer                      6
# Lead Data Engineer                            6
# BI Data Analyst                               6
# ML Engineer                                   6
# Data Engineering Manager                      5
# Business Data Analyst                         5
# ...

# %%
#research Scientist, Data Scientist,Data Science Manager,Applied Data Scientist,Head of Data Science,Data Science Engineer,Lead Data Scientist,
#Staff Data Scientist

# %%
train2['job_title'].replace(['research Scientist'],['Data Scientist'], inplace=True)

# %%
'Data Scientist', 'Data Science Manager','Applied Data Scientist','Head of Data Science','Data Science Engineer','Lead Data Scientist'
# Out:
# ('Data Scientist',
#  'Data Science Manager',
#  'Applied Data Scientist',
#  'Head of Data Science',
#  'Data Science Engineer',
#  'Lead Data Scientist')

# %%
train2['job_title'].replace(['Data Science Manager'],['Data Scientist'], inplace=True)

# %%
train2['job_title'].replace(['Applied Data Scientist'],['Data Scientist'], inplace=True)

# %%
train2['job_title'].replace(['Head of Data Science'],['Data Scientist'], inplace=True)

# %%
train2['job_title'].replace(['Data Science Engineer'],['Data Scientist'], inplace=True)

# %%
train2['job_title'].replace(['Lead Data Scientist'],['Data Scientist'], inplace=True)

# %%
train2['job_title'].replace(['AI Scientist'],['Data Scientist'], inplace=True)

# %%
train2.job_title.value_counts()
# Out:
# Data Scientist                              177
# Data Engineer                               132
# Data Analyst                                 97
# Machine Learning Engineer                    41
# Research Scientist                           16
# Data Architect                               11
# Machine Learning Scientist                    8
# Big Data Engineer                             8
# Director of Data Science                      7
# Principal Data Scientist                      7
# Data Analytics Manager                        7
# Data Science Consultant                       7
# BI Data Analyst                               6
# Lead Data Engineer                            6
# Computer Vision Engineer                      6
# ML Engineer                                   6
# Data Engineering Manager                      5
# Head of Data                                  5
# Business Data Analyst                         5
# Analytics Engineer                            4
# ...

# %%
train2['job_title'][train2['job_title'].str.endswith('Scientist')] = 'Data Scientist'

# %%
train2['job_title'][train2['job_title'].str.startswith('Scientist')] = 'Data Scientist'

# %%
train2.job_title.value_counts()
# Out:
# Data Scientist                              213
# Data Engineer                               132
# Data Analyst                                 97
# Machine Learning Engineer                    41
# Data Architect                               11
# Big Data Engineer                             8
# Director of Data Science                      7
# Data Analytics Manager                        7
# Data Science Consultant                       7
# ML Engineer                                   6
# BI Data Analyst                               6
# Lead Data Engineer                            6
# Computer Vision Engineer                      6
# Data Engineering Manager                      5
# Business Data Analyst                         5
# Head of Data                                  5
# Analytics Engineer                            4
# Data Analytics Engineer                       4
# Machine Learning Infrastructure Engineer      3
# Lead Data Analyst                             3
# ...

# %%
train2['job_title'][train2['job_title'].str.endswith('Analyst')] = 'Data Analyst'

# %%
train2['job_title'][train2['job_title'].str.startswith('Analyst')] = 'Data Analyst'

# %%
train2.job_title.value_counts()
# Out:
# Data Scientist                              213
# Data Engineer                               132
# Data Analyst                                119
# Machine Learning Engineer                    41
# Data Architect                               11
# Big Data Engineer                             8
# Data Analytics Manager                        7
# Director of Data Science                      7
# Data Science Consultant                       7
# ML Engineer                                   6
# Computer Vision Engineer                      6
# Lead Data Engineer                            6
# Data Engineering Manager                      5
# Head of Data                                  5
# Data Analytics Engineer                       4
# Analytics Engineer                            4
# Machine Learning Infrastructure Engineer      3
# Machine Learning Developer                    3
# Computer Vision Software Engineer             3
# Principal Data Engineer                       3
# ...

# %%
train2['job_title'][train2['job_title'].str.endswith('Machine Learning')] = 'Machine Learning Engineer'

# %%
train2['job_title'][train2['job_title'].str.startswith('Machine Learning')] = 'Machine Learning Engineer'

# %%
train2.job_title.value_counts()
# Out:
# Data Scientist                       213
# Data Engineer                        132
# Data Analyst                         119
# Machine Learning Engineer             49
# Data Architect                        11
# Big Data Engineer                      8
# Data Analytics Manager                 7
# Director of Data Science               7
# Data Science Consultant                7
# ML Engineer                            6
# Computer Vision Engineer               6
# Lead Data Engineer                     6
# Data Engineering Manager               5
# Head of Data                           5
# Data Analytics Engineer                4
# Analytics Engineer                     4
# Computer Vision Software Engineer      3
# Principal Data Engineer                3
# ETL Developer                          2
# Cloud Data Engineer                    2
# Director of Data Engineering           2
# Data Specialist                        1
# Lead Machine Learning Engineer         1
# ...

# %%
train2['job_title'].replace(['Data Analytics Manager'],['Data Analyst'], inplace=True)

# %%
train2['job_title'].replace(['Big Data Engineer'],['Data Engineer'], inplace=True)

# %%
train2.job_title.value_counts()
# Out:
# Data Scientist                       213
# Data Engineer                        140
# Data Analyst                         126
# Machine Learning Engineer             49
# Data Architect                        11
# Director of Data Science               7
# Data Science Consultant                7
# ML Engineer                            6
# Computer Vision Engineer               6
# Lead Data Engineer                     6
# Data Engineering Manager               5
# Head of Data                           5
# Data Analytics Engineer                4
# Analytics Engineer                     4
# Computer Vision Software Engineer      3
# Principal Data Engineer                3
# Director of Data Engineering           2
# ETL Developer                          2
# Cloud Data Engineer                    2
# Big Data Architect                     1
# Lead Machine Learning Engineer         1
# Data Analytics Lead                    1
# Data Specialist                        1
# ...

# %%
train2['job_title'].replace(['Director of Data Science'],['Data Scientist'], inplace=True)

# %%
train2['job_title'].replace(['Data Science Consultant'],['Data Scientist'], inplace=True)

# %%
train2['job_title'].replace(['Lead Data Engineer'],['Data Engineer'], inplace=True)

# %%
train2['job_title'].replace(['Data Analytics Engineer'],['Data Engineer'], inplace=True)

# %%
train2['job_title'].replace(['Principal Data Engineer'],['Data Engineer'], inplace=True)

# %%
train2['job_title'].replace(['Data Engineering Manager'],['Data Engineer'], inplace=True)

# %%
train2['job_title'].replace(['Analytics Engineer'],['Data Engineer'], inplace=True)

# %%
train2['job_title'].replace(['Computer Vision Engineer'],['Data Engineer'], inplace=True)

# %%
train2['job_title'].replace(['ML Engineer'],['Data Engineer'], inplace=True)

# %%
train2['job_title'].replace(['Computer Vision Software Engineer'],['Data Engineer'], inplace=True)

# %%
train2['job_title'].replace(['Data Analytics Lead'],['Data Analyst'], inplace=True)

# %%
train2['job_title'].replace(['Big Data Architect'],['Data Engineer'], inplace=True)

# %%
train2['job_title'].replace(['Lead Machine Learning Engineer'],['Machine Learning Engineer'], inplace=True)

# %%
train2['job_title'].replace(['Data Architect'],['Data Engineer'], inplace=True)

# %%
train2['job_title'].replace(['Head of Data'],['Data Scientist'], inplace=True)

# %%
train2['job_title'].replace(['Director of Data Engineering'],['Data Engineer'], inplace=True)

# %%
train2['job_title'].replace(['Cloud Data Engineer'],['Data Engineer'], inplace=True)

# %%
train2['job_title'].replace(['ETL Developer'],['Data Engineer'], inplace=True)

# %%
train2['job_title'].replace(['3D Computer Vision Researcher'],['Data Scientist'], inplace=True)

# %%
train2['job_title'].replace(['Data Specialist'],['Data Scientist'], inplace=True)

# %%
train2['job_title'].replace(['NLP Engineer'],['Data Scientist'], inplace=True)

# %%
train2.job_title.value_counts()
# Out:
# Data Scientist               235
# Data Engineer                195
# Data Analyst                 127
# Machine Learning Engineer     50
# Name: job_title, dtype: int64

# %%
train2.job_title
# Out:
# 0       Data Engineer
# 1       Data Engineer
# 2        Data Analyst
# 3       Data Engineer
# 4       Data Engineer
#             ...
# 102      Data Analyst
# 103     Data Engineer
# 104    Data Scientist
# 105      Data Analyst
# 106      Data Analyst
# Name: job_title, Length: 607, dtype: object

# %%
train2
# Out:
#      work_year experience_level employment_type       job_title  \
# 0         2022               SE              FT   Data Engineer
# 1         2022               SE              FT   Data Engineer
# 2         2021               MI              FT    Data Analyst
# 3         2021               MI              CT   Data Engineer
# 4         2021               MI              FT   Data Engineer
# ..         ...              ...             ...             ...
# 102       2022               SE              FT    Data Analyst
# 103       2022               SE              FT   Data Engineer
# 104       2022               SE              FT  Data Scientist
# 105       2022               EN              FT    Data Analyst
# 106       2022               SE              FT    Data Analyst
#
#     employee_residence  remote_ratio company_location company_size
# 0                   US           100               US            M
# ...

# %%
train2.employee_residence.value_counts() #vamos a ver la relevancia de los distintos paises y quitar los que no sean relevantes
# Out:
# US    332
# GB     44
# IN     30
# CA     29
# DE     25
# FR     18
# ES     15
# GR     13
# JP      7
# BR      6
# PT      6
# PK      6
# NL      5
# PL      4
# IT      4
# RU      4
# AU      3
# AE      3
# VN      3
# AT      3
# TR      3
# SG      2
# HU      2
# DK      2
# RO      2
# NG      2
# MX      2
# SI      2
# BE      2
# IE      1
# AR      1
# CO      1
# IQ      1
# HR      1
# PH      1
# CN      1
# MD      1
# LU      1
# MT      1
# BO      1
# MY      1
# HN      1
# UA      1
# NZ      1
# RS      1
# IR      1
# DZ      1
# KE      1
# CH      1
# PR      1
# CL      1
# CZ      1
# EE      1
# HK      1
# BG      1
# JE      1
# TN      1
# Name: employee_residence, dtype: int64

# %%
train2.head() #probar luego a hacer cosas con los paises
# Out:
#    work_year experience_level employment_type      job_title  \
# 0       2022               SE              FT  Data Engineer
# 1       2022               SE              FT  Data Engineer
# 2       2021               MI              FT   Data Analyst
# 3       2021               MI              CT  Data Engineer
# 4       2021               MI              FT  Data Engineer
#
#   employee_residence  remote_ratio company_location company_size
# 0                 US           100               US            M
# 1                 US           100               US            M
# 2                 US           100               US            M
# 3                 US           100               US            L
# 4                 RO             0               US            L

# %%
train2.remote_ratio.value_counts()
# Out:
# 100    381
# 0      127
# 50      99
# Name: remote_ratio, dtype: int64

# %%
train2.company_size.value_counts()
# Out:
# M    326
# L    198
# S     83
# Name: company_size, dtype: int64

# %%
#cols1 =['salary','salary_currency']
#train.drop(columns=cols1, inplace=True)

# %%
cols_categoricas = list(train2.select_dtypes(exclude=["int64", 'float64']).columns)
cols_categoricas
# Out:
# ['experience_level',
#  'employment_type',
#  'job_title',
#  'employee_residence',
#  'company_location',
#  'company_size']

# %%
data = pd.get_dummies(train2, columns=cols_categoricas, drop_first = True)

# %%
data.head()
# Out:
#    work_year  remote_ratio  experience_level_EX  experience_level_MI  \
# 0       2022           100                    0                    0
# 1       2022           100                    0                    0
# 2       2021           100                    0                    1
# 3       2021           100                    0                    1
# 4       2021             0                    0                    1
#
#    experience_level_SE  employment_type_FL  employment_type_FT  \
# 0                    1                   0                   1
# 1                    1                   0                   1
# 2                    0                   0                   1
# 3                    0                   0                   0
# 4                    0                   0                   1
#
#    employment_type_PT  job_title_Data Engineer  job_title_Data Scientist  \
# 0                   0                        1                         0
# ...

# %%
df1= data[0:500]
df2=data[500:]

# %%
X = df1
y = train.salary_in_usd

# %%
X_train, X_test, y_train, y_test = tts(X, y, train_size=0.8, test_size=0.2, random_state=42)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((400, 118), (100, 118), (400,), (100,))

# %%
import warnings
warnings.filterwarnings('ignore')

import pandas as pd

from sklearn.ensemble import RandomForestRegressor as RFR    # el modelo , el alias es cosa mia

from sklearn.model_selection import train_test_split as tts  # el alias es cosa mia

from sklearn.datasets import load_diabetes   # dataset

# %%
# modelo

rf=RFR()   # inicia el modelo

rf.fit(X_train, y_train)   # entrena el modelo, lo ajusta

y_pred=rf.predict(X_test)  # predicc

# %%
from sklearn.metrics import mean_squared_error as mse   

mse(y_test, y_pred, squared=False)
# Out:
# 53150.935637253664

# %%
y_pred1=rf.predict(df2)

# %%
prueba= pd.DataFrame(y_pred1,columns=['salary_in_usd'])

# %%
prueba.to_csv('./data/prueba.csv',index_label='id')
